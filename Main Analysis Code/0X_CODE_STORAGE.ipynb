# %%
predictors = ['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']
school_levels = ('All', 'Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
MIGENED_DESCRIPTIVES = pd.DataFrame(columns=school_levels, index=predictors)

for level in school_levels:
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]

    for predictor in predictors:
        # Define the predictors (X) and the outcome variable (y)
        X = complete_predictors[[predictor]]
        y = complete_predictors['voluntary_missing']

        # Add a constant column to the predictors
        X = sm.add_constant(X)

        # Fit the linear regression model
        model = sm.OLS(y, X)
        results = model.fit()

        # Store coefficient and standard error in the dataframe
        MIGENED_DESCRIPTIVES.loc[predictor, level] = results.params[1]
        MIGENED_DESCRIPTIVES.loc[predictor, level + '_SE'] = results.bse[1]

# %%
MIGENED_DESCRIPTIVES
# Out:
#                          All Elementary School Elementary/Middle School  \
# per_white           0.000375          0.000234                 0.000613
# per_ecodis          0.001029          0.000921                 0.000728
# tot_all            -0.000198         -0.000357                -0.000642
# City               -0.019787         -0.020067                -0.002244
# Rural               0.106249           0.05508                 0.211101
# Suburb             -0.086426         -0.039541                 -0.16974
# Town                0.001698          0.008124                -0.076541
# Not Specified       0.295488          0.407155                 0.809224
# Charter             0.180699          0.272636                 0.092783
# Magnet              0.066699          0.083642                 0.008612
# STRatio             -0.00003          0.007855                 0.001513
# Total Building PPE  0.000002          0.000002                 0.000008
#
# ...

# %%
MIGENED_DESCRIPTIVES.to_csv("C:/Users/johnw/Box/Michigan Parent Dashboard/Tables/MIGENED_DESCRIPTIVES_06_26_23.csv", index=True)

# %% [markdown]
# # General Education Voluntary Missing Regressions [Complete Predictors]

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     27.61
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           2.28e-55
# Time:                        22:29:41   Log-Likelihood:                -693.41
# No. Observations:                2760   AIC:                             1411.
# Df Residuals:                    2748   BIC:                             1482.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0353      0.045     -0.788      0.431      -0.123       0.053
# ...

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.578
# Method:                 Least Squares   F-statistic:                     5.707
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):          7.30e-216
# Time:                        22:30:22   Log-Likelihood:                 825.70
# No. Observations:                2760   AIC:                            -45.39
# Df Residuals:                    1957   BIC:                             4711.
# Df Model:                         802
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2645      0.080      3.323      0.001       0.108       0.421
# ...

# %% [markdown]
# ### Elementary School

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
data = elem_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     9.952
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           1.79e-17
# Time:                        22:30:40   Log-Likelihood:                -169.12
# No. Observations:                1178   AIC:                             362.2
# Df Residuals:                    1166   BIC:                             423.1
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1622      0.090     -1.804      0.072      -0.339       0.014
# ...

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
data = elem_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.449
# Method:                 Least Squares   F-statistic:                     3.096
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           2.63e-42
# Time:                        22:30:50   Log-Likelihood:                 418.26
# No. Observations:                1178   AIC:                             79.48
# Df Residuals:                     720   BIC:                             2402.
# Df Model:                         457
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1209      0.167      0.724      0.469      -0.207       0.449
# ...

# %% [markdown]
# ### Elementary/Middle School

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
data = elemmiddle_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     11.38
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           7.62e-19
# Time:                        22:31:30   Log-Likelihood:                -176.47
# No. Observations:                 478   AIC:                             376.9
# Df Residuals:                     466   BIC:                             427.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.1018      0.132      0.770      0.442      -0.158       0.362
# ...

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
data = elemmiddle_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     7.092
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           1.02e-23
# Time:                        22:31:38   Log-Likelihood:                 563.74
# No. Observations:                 478   AIC:                            -369.5
# Df Residuals:                      99   BIC:                             1211.
# Df Model:                         378
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.5474      0.273      2.007      0.048       0.006       1.089
# ...

# %% [markdown]
# ### Elementary/High School

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
data = elemhigh_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     1.908
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):             0.0438
# Time:                        22:32:10   Log-Likelihood:                -73.666
# No. Observations:                 141   AIC:                             171.3
# Df Residuals:                     129   BIC:                             206.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0725      0.229     -0.316      0.752      -0.526       0.381
# ...

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
data = elemhigh_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
# C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1749: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1749: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\base\model.py:1512: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       1.000
# ...

# %% [markdown]
# ### Middle School

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
data = middle_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     5.796
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           1.29e-08
# Time:                        22:32:32   Log-Likelihood:                -29.563
# No. Observations:                 355   AIC:                             83.13
# Df Residuals:                     343   BIC:                             129.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.5677      0.171      3.324      0.001       0.232       0.904
# ...

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
data = middle_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     4.690
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           1.73e-11
# Time:                        22:32:43   Log-Likelihood:                 490.86
# No. Observations:                 355   AIC:                            -399.7
# Df Residuals:                      64   BIC:                             727.1
# Df Model:                         290
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.3612      0.342      1.057      0.294      -0.321       1.044
# ...

# %% [markdown]
# ### Middle/High

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
data = middlehigh_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     3.869
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           8.70e-05
# Time:                        22:33:00   Log-Likelihood:                -53.530
# No. Observations:                 199   AIC:                             129.1
# Df Residuals:                     188   BIC:                             165.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.4955      0.270      1.837      0.068      -0.037       1.028
# ...

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
data = middlehigh_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.571e+21
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):          2.70e-188
# Time:                        22:33:08   Log-Likelihood:                 5013.1
# No. Observations:                 199   AIC:                            -9664.
# Df Residuals:                      18   BIC:                            -9068.
# Df Model:                         180
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1286   6.59e-11   1.95e+09      0.000       0.129       0.129
# ...

# %% [markdown]
# ### High School

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
data = high_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     5.257
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           9.20e-08
# Time:                        22:33:21   Log-Likelihood:                -46.676
# No. Observations:                 409   AIC:                             117.4
# Df Residuals:                     397   BIC:                             165.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0555      0.129     -0.429      0.668      -0.310       0.199
# ...

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
data = high_complete_predictors[['voluntary_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['voluntary_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      voluntary_missing   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     3.284
# Date:                Mon, 26 Jun 2023   Prob (F-statistic):           1.05e-06
# Time:                        22:33:30   Log-Likelihood:                 579.74
# No. Observations:                 409   AIC:                            -441.5
# Df Residuals:                      50   BIC:                             999.5
# Df Model:                         358
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.4467      0.316     -1.413      0.164      -1.082       0.188
# ...

# %% [markdown]
# ### Other [Cannot be Done since Only 1 in General Education Schools]

# %%
MIGENED_OTHER = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Other'] == 1]

# %%
MIGENED_OTHER
# Out:
#       Unnamed: 0  DistrictCode                                District Name  \
# 1167        1614         47000  Livingston ESA  - District created from ISD
#
#                                               Core Link School Level  \
# 1167  https://legacy.mischooldata.org/ParentDashboar...        Other
#
#                          BuildingName_x School Grade  \
# 1167  Livingston County Adult Education            -
#
#                                             School Link  \
# 1167  https://legacy.mischooldata.org/ParentDashboar...
#
#                                           Offering Link  ACS_CTE_AGFN  ...  \
# 1167  https://legacy.mischooldata.org/ParentDashboar...             0  ...
#
#       districtdummy_82995  districtdummy_82996  districtdummy_82997  \
# 1167                    0                    0                    0
#
#       districtdummy_83000  districtdummy_83010  districtdummy_83060  \
# 1167                    0                    0                    0
#
# ...

# %% [markdown]
# # Verification Checks

# %%
#Checking How many Missing for each
CHECK_list = ['CHECK_BASEBALL', 'CHECK_BSKTBALL', 'CHECK_BOWLING', 'CHECK_COMPCHEER', 'CHECK_CROSSCNTRY', 'CHECK_FOOTBALL', 'CHECK_GOLF', 'CHECK_GYMNAST', 'CHECK_ICEHOCKEY', 'CHECK_SKIING', 'CHECK_SOFTBALL', 'CHECK_SOCCER', 'CHECK_SWIM', 'CHECK_TENNIS', 'CHECK_TRCKFIELD', 'CHECK_VOLBALL', 'CHECK_WRSTL']
​
nosketchypercentages = []  # List to store the percentages
​
for check in CHECK_list:   
    unique_values = HSCHECKYESEXTRACURRICULARLIST[check].unique()
    value_counts = HSCHECKYESEXTRACURRICULARLIST[check].value_counts()
    zero_count = value_counts.get(0, 0)  # Get the count of zeros, defaulting to 0 if not found
    total_count = len(HSCHECKYESEXTRACURRICULARLIST)
    percentage = zero_count / total_count * 100
    nosketchypercentages.append(percentage)  # Add the percentage to the list
    
#Final Average Accuracy
average_percentage = sum(nosketchypercentages) / len(nosketchypercentages)  # Calculate the average percentage
​
print(f"Average percentage of values equal to zero: {average_percentage:.2f}%")
Average percentage of values equal to zero: 94.38%
#Converting all CHECK_list values into positive then following up with regressions
CHECK_list = ['CHECK_BASEBALL', 'CHECK_BSKTBALL', 'CHECK_BOWLING', 'CHECK_DIVING', 'CHECK_COMPCHEER', 'CHECK_CROSSCNTRY', 'CHECK_FOOTBALL', 'CHECK_GOLF', 'CHECK_GYMNAST', 'CHECK_ICEHOCKEY', 'CHECK_OTHSPRTS', 'CHECK_POWERLIFT', 'CHECK_SKIING', 'CHECK_SOFTBALL', 'CHECK_SOCCER', 'CHECK_SWIM', 'CHECK_TENNIS', 'CHECK_TRCKFIELD', 'CHECK_VOLBALL', 'CHECK_WRSTL']
​
for check in CHECK_list:
    HSCHECKYESEXTRACURRICULARLIST[check] = HSCHECKYESEXTRACURRICULARLIST[check].abs()
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_BASEBALL', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_BASEBALL']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
                            OLS Regression Results                            
==============================================================================
Dep. Variable:         CHECK_BASEBALL   R-squared:                         nan
Model:                            OLS   Adj. R-squared:                    nan
Method:                 Least Squares   F-statistic:                       nan
Date:                Tue, 27 Jun 2023   Prob (F-statistic):                nan
Time:                        22:16:06   Log-Likelihood:                    inf
No. Observations:                  62   AIC:                              -inf
Df Residuals:                      52   BIC:                              -inf
Df Model:                           9                                         
Covariance Type:            nonrobust                                         
=================================================================================
                    coef    std err          t      P>|t|      [0.025      0.975]
---------------------------------------------------------------------------------
const                  0          0        nan        nan           0           0
per_white              0          0        nan        nan           0           0
per_ecodis             0          0        nan        nan           0           0
tot_all                0          0        nan        nan           0           0
City                   0          0        nan        nan           0           0
Rural                  0          0        nan        nan           0           0
Town                   0          0        nan        nan           0           0
Not Specified          0          0        nan        nan           0           0
Charter                0          0        nan        nan           0           0
Magnet                 0          0        nan        nan           0           0
STRatio                0          0        nan        nan           0           0
==============================================================================
Omnibus:                          nan   Durbin-Watson:                     nan
Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
Skew:                             nan   Prob(JB):                          nan
Kurtosis:                         nan   Cond. No.                     1.87e+20
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
[2] The smallest eigenvalue is 1.33e-33. This might indicate that there are
strong multicollinearity problems or that the design matrix is singular.
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
  return 1 - self.ssr/self.centered_tss
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1825: RuntimeWarning: invalid value encountered in double_scalars
  return self.mse_model/self.mse_resid
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
  llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
  dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_BSKTBALL', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_BSKTBALL']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
                            OLS Regression Results                            
==============================================================================
Dep. Variable:         CHECK_BSKTBALL   R-squared:                         nan
Model:                            OLS   Adj. R-squared:                    nan
Method:                 Least Squares   F-statistic:                       nan
Date:                Tue, 27 Jun 2023   Prob (F-statistic):                nan
Time:                        22:16:07   Log-Likelihood:                    inf
No. Observations:                  62   AIC:                              -inf
Df Residuals:                      52   BIC:                              -inf
Df Model:                           9                                         
Covariance Type:            nonrobust                                         
=================================================================================
                    coef    std err          t      P>|t|      [0.025      0.975]
---------------------------------------------------------------------------------
const                  0          0        nan        nan           0           0
per_white              0          0        nan        nan           0           0
per_ecodis             0          0        nan        nan           0           0
tot_all                0          0        nan        nan           0           0
City                   0          0        nan        nan           0           0
Rural                  0          0        nan        nan           0           0
Town                   0          0        nan        nan           0           0
Not Specified          0          0        nan        nan           0           0
Charter                0          0        nan        nan           0           0
Magnet                 0          0        nan        nan           0           0
STRatio                0          0        nan        nan           0           0
==============================================================================
Omnibus:                          nan   Durbin-Watson:                     nan
Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
Skew:                             nan   Prob(JB):                          nan
Kurtosis:                         nan   Cond. No.                     1.87e+20
==============================================================================

Notes:
[1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
[2] The smallest eigenvalue is 1.33e-33. This might indicate that there are
strong multicollinearity problems or that the design matrix is singular.
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1736: RuntimeWarning: invalid value encountered in double_scalars
  return 1 - self.ssr/self.centered_tss
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1825: RuntimeWarning: invalid value encountered in double_scalars
  return self.mse_model/self.mse_resid
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:924: RuntimeWarning: divide by zero encountered in log
  llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
C:\Users\johnw\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in double_scalars
  dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_BOWLING', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_BOWLING']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_DIVING', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_DIVING']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_COMPCHEER', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_COMPCHEER']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_CROSSCNTRY', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_CROSSCNTRY']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_FOOTBALL', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_FOOTBALL']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_GOLF', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_GOLF']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_GYMNAST', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_GYMNAST']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_ICEHOCKEY', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_ICEHOCKEY']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_OTHSPRTS', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_OTHSPRTS']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_POWERLIFT', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_POWERLIFT']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_SKIING', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_SKIING']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_SOFTBALL', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_SOFTBALL']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_SOCCER', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_SOCCER']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_SWIM', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_SWIM']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_TENNIS', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_TENNIS']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_TRCKFIELD', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_TRCKFIELD']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
data = HSCHECKYESEXTRACURRICULARLIST[['CHECK_VOLBALL', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio']]
y = data['CHECK_VOLBALL']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())

# %%
MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
# Out:
#       Unnamed: 0  DistrictCode  \
# 16            20          3020
# 17            21          3020
# 30            37          3040
# 31            38          3040
# 34            41          3050
# ...          ...           ...
# 2622        3635         82701
# 2625        3638         82702
# 2694        3717         82926
# 2703        3726         82938
# 2752        3788         83010
#
#                                        District Name  \
# 16                             Otsego Public Schools
# 17                             Otsego Public Schools
# 30                             Wayland Union Schools
# 31                             Wayland Union Schools
# 34                          Fennville Public Schools
# ...                                              ...
# 2622  University Preparatory Science and Math (PSAD)
# 2625           University Preparatory Academy (PSAD)
# 2694                              Henry Ford Academy
# ...

# %%
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
coverage = {}

for level in school_levels:
    
    #N+% for Each Level
    total_school_level = len(MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1])
    pct_total_school_level = total_school_level / total_school_level * 100
    
    #N=% for Each Level AND Not Voluntary Missing
    yesvoluntary_total_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA['voluntary_missing'] == 0) & (MIGENEDUSCHOOLDATA[level] == 1)])
    pct_yesvoluntary_total_school_level = yesvoluntary_total_school_level / total_school_level * 100    
    
    #Filter to those that have complete predictors
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    
    #N+% for Each Level with Complete Predictors
    total_school_level_complete_predictors = len(complete_predictors)
    pct_complete_predictors = total_school_level_complete_predictors / total_school_level * 100
    
    #N+% for Each Level with Complete Data AND Not Voluntary Missing
    total_yesvoluntary_complete_predictors = len(complete_predictors[complete_predictors['voluntary_missing'] == 0])
    pct_tyvcp_cp = total_yesvoluntary_complete_predictors / len(complete_predictors) * 100
      
    # Save values and percentages in the dictionary
    coverage[level] = {
        'Total Level (N)': total_school_level,
        'Total Level (%)': pct_total_school_level,
        'Yes Voluntary Info (N)': yesvoluntary_total_school_level,
        'Yes Voluntary Info (%)': pct_yesvoluntary_total_school_level,
        'Complete Predictors (N)': total_school_level_complete_predictors,
        'Complete Predictors (%)': pct_complete_predictors,
        'Yes Voluntary Info AND Complete Predictors (N)': total_yesvoluntary_complete_predictors,
        'Yes Voluntary Info AND Complete Predictors / CP (%)': pct_tyvcp_cp
    }

# Convert the dictionary into a dataframe
MIGENED_COVERAGE = pd.DataFrame(coverage)

# Transpose the dataframe to have school levels as columns
MIGENED_COVERAGE = MIGENED_COVERAGE.transpose()

# %%
MIGENED_COVERAGE
# Out:
#                                 Total Level (N)  Total Level (%)  \
# All                                      2759.0            100.0
# Elementary School                        1178.0            100.0
# Elementary/Middle School                  478.0            100.0
# Elementary through High School            140.0            100.0
# Middle School                             355.0            100.0
# Middle/High School                        199.0            100.0
# High School                               409.0            100.0
#
#                                 Yes Voluntary Info (N)  \
# All                                             2422.0
# Elementary School                               1067.0
# Elementary/Middle School                         386.0
# Elementary through High School                   104.0
# Middle School                                    323.0
# Middle/High School                               171.0
# High School                                      371.0
# ...

# %%
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
coverage = {}

for level in school_levels:
    
    #N+% for Each Level
    total_school_level = len(MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1])
    pct_total_school_level = total_school_level / total_school_level * 100
    
    #N=% for Each Level AND Not Extracurricular Missing
    yesextracurricular_total_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA['extracurricular_missing'] == 0) & (MIGENEDUSCHOOLDATA[level] == 1)])
    pct_yesextracurricular_total_school_level = yesextracurricular_total_school_level / total_school_level * 100    
    
    #Filter to those that have complete predictors
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    
    #N+% for Each Level with Complete Predictors
    total_school_level_complete_predictors = len(complete_predictors)
    pct_complete_predictors = total_school_level_complete_predictors / total_school_level * 100
    
    #N+% for Each Level with Complete Data AND Not Voluntary Missing
    total_yesextracurricular_complete_predictors = len(complete_predictors[complete_predictors['extracurricular_missing'] == 0])
    pct_tyeccp_cp = total_yesextracurricular_complete_predictors / len(complete_predictors) * 100
      
    # Save values and percentages in the dictionary
    coverage[level] = {
        'Total Level (N)': total_school_level,
        'Total Level (%)': pct_total_school_level,
        'Yes Extracurricular Info (N)': yesextracurricular_total_school_level,
        'Yes Extracurricular Info (%)': pct_yesextracurricular_total_school_level,
        'Complete Predictors (N)': total_school_level_complete_predictors,
        'Complete Predictors (%)': pct_complete_predictors,
        'Yes Extracurricular Info AND Complete Predictors (N)': total_yesextracurricular_complete_predictors,
        'Yes Extracurricular Info AND Complete Predictors / CP (%)': pct_tyeccp_cp
    }

# Convert the dictionary into a dataframe
MIGENED_COVERAGE_EXTRACURRICULAR = pd.DataFrame(coverage)

# Transpose the dataframe to have school levels as columns
MIGENED_COVERAGE_EXTRACURRICULAR = MIGENED_COVERAGE_EXTRACURRICULAR.transpose()

# %%
MIGENED_COVERAGE_EXTRACURRICULAR
# Out:
#                                 Total Level (N)  Total Level (%)  \
# All                                      2759.0            100.0
# Elementary School                        1178.0            100.0
# Elementary/Middle School                  478.0            100.0
# Elementary through High School            140.0            100.0
# Middle School                             355.0            100.0
# Middle/High School                        199.0            100.0
# High School                               409.0            100.0
#
#                                 Yes Extracurricular Info (N)  \
# All                                                   1550.0
# Elementary School                                      634.0
# Elementary/Middle School                               219.0
# Elementary through High School                          59.0
# Middle School                                          235.0
# Middle/High School                                     133.0
# ...

# %%
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
coverage = {}

for level in school_levels:
    
    #N+% for Each Level with Voluntary Information
    total_voluntary_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA[level] == 1) & (MIGENEDUSCHOOLDATA['voluntary_missing'] == 0)])
    pct_total_voluntary_school_level = total_voluntary_school_level / total_voluntary_school_level * 100
    
    #N=% for Each Level AND Not Voluntary Missing AND Not Extracurricular Missing
    yesvoluntaryextracurricular_total_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA['voluntary_missing'] == 0) & (MIGENEDUSCHOOLDATA['extracurricular_missing'] == 0) & (MIGENEDUSCHOOLDATA[level] == 1)])
    pct_yesvoluntaryextracurricular_total_school_level = yesvoluntaryextracurricular_total_school_level / total_voluntary_school_level * 100
    
    #Filter to those that have complete predictors AND Not Voluntary Missing
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    complete_predictors = complete_predictors[complete_predictors['voluntary_missing'] == 0]
    
    #N+% for Each Level with Complete Predictors AND Not Voluntary Missing
    total_school_level_complete_predictors = len(complete_predictors)
    pct_complete_predictors = total_school_level_complete_predictors / total_voluntary_school_level * 100
    
    #N+% for Each Level with Complete Data AND Not Voluntary Missing AND Not Extracurricular Missing
    total_yesvoluntaryextracurricular_complete_predictors = len(complete_predictors[(complete_predictors['voluntary_missing'] == 0) & (complete_predictors['extracurricular_missing'] == 0)])
    pct_tyveccp_cp = total_yesvoluntaryextracurricular_complete_predictors / len(complete_predictors) * 100
      
    # Save values and percentages in the dictionary
    coverage[level] = {
        'Total Voluntary Level (N)': total_voluntary_school_level,
        'Total Voluntary Level (%)': pct_total_voluntary_school_level,
        'Yes Voluntary & Extracurricular Info (N)': yesvoluntaryextracurricular_total_school_level,
        'Yes Voluntary & Extracurricular Info (%)': pct_yesvoluntaryextracurricular_total_school_level,
        'Complete Voluntary Predictors (N)': total_school_level_complete_predictors,
        'Complete Voluntary Predictors (%)': pct_complete_predictors,
        'Yes Voluntary & Extracurricular Info AND Complete Predictors (N)': total_yesvoluntaryextracurricular_complete_predictors,
        'Yes Voluntary & Extracurricular Info AND Complete Predictors / CP (%)': pct_tyveccp_cp
    }

# Convert the dictionary into a dataframe
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR = pd.DataFrame(coverage)

# Transpose the dataframe to have school levels as columns
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR = MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR.transpose()

# %%
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR
# Out:
#                                 Total Voluntary Level (N)  \
# All                                                2422.0
# Elementary School                                  1067.0
# Elementary/Middle School                            386.0
# Elementary through High School                      104.0
# Middle School                                       323.0
# Middle/High School                                  171.0
# High School                                         371.0
#
#                                 Total Voluntary Level (%)  \
# All                                                 100.0
# Elementary School                                   100.0
# Elementary/Middle School                            100.0
# Elementary through High School                      100.0
# Middle School                                       100.0
# Middle/High School                                  100.0
# High School                                         100.0
#
# ...

# %%
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
coverage = {}

for level in school_levels:
    
    #N+% for Each Level
    total_school_level = len(MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1])
    pct_total_school_level = total_school_level / total_school_level * 100
    
    #N=% for Each Level AND Not Extracurricular Missing
    yesextracurricular_total_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA['extracurricular_missing'] == 0) & (MIGENEDUSCHOOLDATA[level] == 1)])
    pct_yesextracurricular_total_school_level = yesextracurricular_total_school_level / total_school_level * 100    
    
    #Filter to those that have complete predictors
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    
    #N+% for Each Level with Complete Predictors
    total_school_level_complete_predictors = len(complete_predictors)
    pct_complete_predictors = total_school_level_complete_predictors / total_school_level * 100
    
    #N+% for Each Level with Complete Data AND Not Voluntary Missing
    total_yesextracurricular_complete_predictors = len(complete_predictors[complete_predictors['extracurricular_missing'] == 0])
    pct_tyeccp_cp = total_yesextracurricular_complete_predictors / len(complete_predictors) * 100
      
    # Save values and percentages in the dictionary
    coverage[level] = {
        'Total Level (N)': total_school_level,
        'Total Level (%)': pct_total_school_level,
        'Yes Extracurricular Info (N)': yesextracurricular_total_school_level,
        'Yes Extracurricular Info (%)': pct_yesextracurricular_total_school_level,
        'Complete Predictors (N)': total_school_level_complete_predictors,
        'Complete Predictors (%)': pct_complete_predictors,
        'Yes Extracurricular Info AND Complete Predictors (N)': total_yesextracurricular_complete_predictors,
        'Yes Extracurricular Info AND Complete Predictors / CP (%)': pct_tyeccp_cp
    }

# Convert the dictionary into a dataframe
MIGENED_COVERAGE_EXTRACURRICULAR = pd.DataFrame(coverage)

# Transpose the dataframe to have school levels as columns
MIGENED_COVERAGE_EXTRACURRICULAR = MIGENED_COVERAGE_EXTRACURRICULAR.transpose()

# %%
MIGENED_COVERAGE_EXTRACURRICULAR
# Out:
#                                 Total Level (N)  Total Level (%)  \
# All                                      2759.0            100.0
# Elementary School                        1178.0            100.0
# Elementary/Middle School                  478.0            100.0
# Elementary through High School            140.0            100.0
# Middle School                             355.0            100.0
# Middle/High School                        199.0            100.0
# High School                               409.0            100.0
#
#                                 Yes Extracurricular Info (N)  \
# All                                                   1550.0
# Elementary School                                      634.0
# Elementary/Middle School                               219.0
# Elementary through High School                          59.0
# Middle School                                          235.0
# Middle/High School                                     133.0
# ...

# %%
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
coverage = {}

for level in school_levels:
    
    #N+% for Each Level with Voluntary Information
    total_voluntary_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA[level] == 1) & (MIGENEDUSCHOOLDATA['voluntary_missing'] == 0)])
    pct_total_voluntary_school_level = total_voluntary_school_level / total_voluntary_school_level * 100
    
    #N=% for Each Level AND Not Voluntary Missing AND Not Extracurricular Missing
    yesvoluntaryextracurricular_total_school_level = len(MIGENEDUSCHOOLDATA[(MIGENEDUSCHOOLDATA['voluntary_missing'] == 0) & (MIGENEDUSCHOOLDATA['extracurricular_missing'] == 0) & (MIGENEDUSCHOOLDATA[level] == 1)])
    pct_yesvoluntaryextracurricular_total_school_level = yesvoluntaryextracurricular_total_school_level / total_voluntary_school_level * 100
    
    #Filter to those that have complete predictors AND Not Voluntary Missing
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    complete_predictors = complete_predictors[complete_predictors['voluntary_missing'] == 0]
    
    #N+% for Each Level with Complete Predictors AND Not Voluntary Missing
    total_school_level_complete_predictors = len(complete_predictors)
    pct_complete_predictors = total_school_level_complete_predictors / total_voluntary_school_level * 100
    
    #N+% for Each Level with Complete Data AND Not Voluntary Missing AND Not Extracurricular Missing
    total_yesvoluntaryextracurricular_complete_predictors = len(complete_predictors[(complete_predictors['voluntary_missing'] == 0) & (complete_predictors['extracurricular_missing'] == 0)])
    pct_tyveccp_cp = total_yesvoluntaryextracurricular_complete_predictors / len(complete_predictors) * 100
      
    # Save values and percentages in the dictionary
    coverage[level] = {
        'Total Voluntary Level (N)': total_voluntary_school_level,
        'Total Voluntary Level (%)': pct_total_voluntary_school_level,
        'Yes Voluntary & Extracurricular Info (N)': yesvoluntaryextracurricular_total_school_level,
        'Yes Voluntary & Extracurricular Info (%)': pct_yesvoluntaryextracurricular_total_school_level,
        'Complete Voluntary Predictors (N)': total_school_level_complete_predictors,
        'Complete Voluntary Predictors (%)': pct_complete_predictors,
        'Yes Voluntary & Extracurricular Info AND Complete Predictors (N)': total_yesvoluntaryextracurricular_complete_predictors,
        'Yes Voluntary & Extracurricular Info AND Complete Predictors / CP (%)': pct_tyveccp_cp
    }

# Convert the dictionary into a dataframe
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR = pd.DataFrame(coverage)

# Transpose the dataframe to have school levels as columns
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR = MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR.transpose()

# %%
MIGENED_COVERAGE_YES_VOLUNTARY_EXTRACURRICULAR
# Out:
#                                 Total Voluntary Level (N)  \
# All                                                2422.0
# Elementary School                                  1067.0
# Elementary/Middle School                            386.0
# Elementary through High School                      104.0
# Middle School                                       323.0
# Middle/High School                                  171.0
# High School                                         371.0
#
#                                 Total Voluntary Level (%)  \
# All                                                 100.0
# Elementary School                                   100.0
# Elementary/Middle School                            100.0
# Elementary through High School                      100.0
# Middle School                                       100.0
# Middle/High School                                  100.0
# High School                                         100.0
#
# ...

# %%
predictors = ['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE', 'per_africanamerican', 'per_hispanic', 'per_whiteasian', 'per_blackorhisp', 'per_asian', 'per_other']
school_levels = ('All', 'Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR = pd.DataFrame(columns=school_levels, index=predictors)

for level in school_levels:
    complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA[level] == 1].notnull().all(axis=1)]
    complete_predictors = complete_predictors[complete_predictors['voluntary_missing'] == 0]

    for predictor in predictors:
        # Define the predictors (X) and the outcome variable (y)
        X = complete_predictors[[predictor]]
        y = complete_predictors['extracurricular_missing']

        # Add a constant column to the predictors
        X = sm.add_constant(X)

        # Fit the linear regression model
        model = sm.OLS(y, X)
        results = model.fit()

        # Store coefficient and standard error in the dataframe
        MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR.loc[predictor, level] = results.params[1]
        MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR.loc[predictor, level + '_SE'] = results.bse[1]

# %%
MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR

# %%
MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR.to_csv("C:/Users/johnw/Box/Michigan Parent Dashboard/Tables/MIGENED_DESCRIPTIVES_VOLUNTARY_EXTRACURRICULAR_06_26_23.csv", index=True)

# %%
rs]
All
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary School
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
data = elem_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
data = elem_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary/Middle School
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary/High School
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Middle School
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
data = middle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
data = middle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Middle/High
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
High School
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
data = high_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
data = high_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Other [Cannot be Done since Only 1 in General Education Schools]
MIGENED_OTHER = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Other'] == 1]
MIGENED_OTHER
General Education Yes Voluntary Extracurricular Missing Regressions [Complete Predictors]
All
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary School
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary/Middle School
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Elementary/High School
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Middle School
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
Middle/High
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())
High School
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()
​
# Drop any rows with missing values
data = data.dropna()
​
# Define the predictors (X) and the outcome variable (y)
X = data[['per_white', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']
​
# Add a constant column to the predictors
X = sm.add_constant(X)
​
# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()
​
# Print the regression summary
print(results.summary())

# %% [markdown]
# # General Education Yes Voluntary Extracurricular Missing Regressions [Complete Predictors] - NONWHITE

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary School

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/Middle School

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/High School

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle School

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle/High

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### High School

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# # General Education Yes Voluntary Extracurricular Missing Regressions [Complete Predictors] - NONWHITE

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary School

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/Middle School

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/High School

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle School

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle/High

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### High School

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# # General Education Yes Voluntary Extracurricular Missing Regressions [Complete Predictors] - NONWHITE

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
all_complete_predictors = all_complete_predictors[all_complete_predictors['voluntary_missing'] == 0]
data = all_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary School

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elem_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary School'] == 1].notnull().all(axis=1)]
elem_complete_predictors = elem_complete_predictors[elem_complete_predictors['voluntary_missing'] == 0]
data = elem_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/Middle School

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemmiddle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary/Middle School'] == 1].notnull().all(axis=1)]
elemmiddle_complete_predictors = elemmiddle_complete_predictors[elemmiddle_complete_predictors['voluntary_missing'] == 0]
data = elemmiddle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Elementary/High School

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
elemhigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Elementary through High School'] == 1].notnull().all(axis=1)]
elemhigh_complete_predictors = elemhigh_complete_predictors[elemhigh_complete_predictors['voluntary_missing'] == 0]
data = elemhigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle School

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middle_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle School'] == 1].notnull().all(axis=1)]
middle_complete_predictors = middle_complete_predictors[middle_complete_predictors['voluntary_missing'] == 0]
data = middle_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### Middle/High

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
middlehigh_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['Middle/High School'] == 1].notnull().all(axis=1)]
middlehigh_complete_predictors = middlehigh_complete_predictors[middlehigh_complete_predictors['voluntary_missing'] == 0]
data = middlehigh_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ### High School

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
high_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['High School'] == 1].notnull().all(axis=1)]
high_complete_predictors = high_complete_predictors[high_complete_predictors['voluntary_missing'] == 0]
data = high_complete_predictors[['extracurricular_missing', 'per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_africanamerican', 'per_hispanic', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# # General Education Extracurricular Missing Regressions [Complete Predictors] - NONWHITE - BLACKHISPANIC

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_blackorhisp', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_blackorhisp', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_blackorhisp', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_blackorhisp', 'per_asian', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# # General Education Extracurricular Missing Regressions [Complete Predictors] - NONWHITE - BLACKHISPANIC - ASIANWHITE

# %% [markdown]
# ### All

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_blackorhisp', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_blackorhisp', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE']]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %%
all_complete_predictors = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].loc[MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA['All'] == 1].notnull().all(axis=1)]
data = all_complete_predictors[['extracurricular_missing', 'per_blackorhisp', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Suburb', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns].copy()

# Drop any rows with missing values
data = data.dropna()

# Define the predictors (X) and the outcome variable (y)
X = data[['per_blackorhisp', 'per_other', 'per_ecodis', 'tot_all', 'City', 'Rural', 'Town', 'Not Specified', 'Charter', 'Magnet', 'STRatio', 'Total Building PPE'] + districtdummy_columns]
y = data['extracurricular_missing']

# Add a constant column to the predictors
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X)
results = model.fit()

# Print the regression summary
print(results.summary())

# %% [markdown]
# ## Samples

# %%
MIGENEDCOMPLETE = MIGENEDUSCHOOLDATA[MIGENEDUSCHOOLDATA.notnull().all(axis=1)]
MIGENEDCOMPLETEVOLUNTARY = MIGENEDCOMPLETE[MIGENEDCOMPLETE['voluntary_missing'] == 0]
MIGENEDCOMPLETEVOLUNTARYWITHECA = MIGENEDCOMPLETEVOLUNTARY[MIGENEDCOMPLETEVOLUNTARY['extracurricular_missing'] == 0]

# %% [markdown]
# ### Complete Predictors

# %%
outcomes = ['numextracurricular', 'numclubs', 'numsports', 'EC_CLUBS_CARFOC', 'EC_CLUBS_GAMES', 'EC_CLUBS_HONSOC', 'EC_CLUBS_LITHUM', 'EC_CLUBS_MUSIC', 'EC_CLUBS_NSLEAD', 'EC_CLUBS_OTHCLUB', 'EC_CLUBS_PEERTUTMEN', 'EC_CLUBS_POLGOV', 'EC_CLUBS_ROBOTICS', 'EC_CLUBS_SCHOOLCOM', 'EC_CLUBS_SPCHDEB', 'EC_CLUBS_STEM', 'EC_CLUBS_VISARTS', 'EC_SPORTS_BASEBALL', 'EC_SPORTS_BSKTBALL', 'EC_SPORTS_BOWLING', 'EC_SPORTS_DIVING', 'EC_SPORTS_COMPCHEER', 'EC_SPORTS_CROSSCNTRY', 'EC_SPORTS_FOOTBALL', 'EC_SPORTS_GOLF', 'EC_SPORTS_GYMNAST', 'EC_SPORTS_ICEHOCKEY', 'EC_SPORTS_OTHSPRTS', 'EC_SPORTS_POWERLIFT', 'EC_SPORTS_SKIING', 'EC_SPORTS_SOFTBALL', 'EC_SPORTS_SOCCER', 'EC_SPORTS_SWIM', 'EC_SPORTS_TENNIS', 'EC_SPORTS_TRCKFIELD', 'EC_SPORTS_VOLBALL', 'EC_SPORTS_WRSTL']
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
outcomes_statisics = {}

for level in school_levels:
    sample = MIGENEDCOMPLETE[MIGENEDCOMPLETE[level] == 1]
    outcomes_mean = []
    outcomes_sd = []
    
    for outcome in outcomes:
        
        outcome_mean = sample[outcome].mean()
        outcome_sd = sample[outcome].std()
        
        outcomes_mean.append(outcome_mean)
        outcomes_sd.append(outcome_sd)
    
    outcomes_statisics[level + ' Mean'] = outcomes_mean
    outcomes_statisics[level + ' SD'] = outcomes_sd
    
MIGENEDCOMPLETE_OUTCOMES = pd.DataFrame(outcomes_statisics, index=outcomes)

# %%
MIGENEDCOMPLETE_OUTCOMES

# %%
MIGENEDCOMPLETE_OUTCOMES.to_csv("C:/Users/johnw/Box/Michigan Parent Dashboard/Tables/MIGENEDCOMPLETE_OUTCOMES_06_26_23.csv", index=True)

# %%
# Sample data for numextracurricular
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETE[MIGENEDCOMPLETE[level] == 1]['numextracurricular'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numextracurricular')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numclubs
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETE[MIGENEDCOMPLETE[level] == 1]['numclubs'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numclubs')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numsports
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETE[MIGENEDCOMPLETE[level] == 1]['numsports'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numsports')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Complete Predictors AND Voluntary Information

# %%
outcomes = ['numextracurricular', 'numclubs', 'numsports', 'EC_CLUBS_CARFOC', 'EC_CLUBS_GAMES', 'EC_CLUBS_HONSOC', 'EC_CLUBS_LITHUM', 'EC_CLUBS_MUSIC', 'EC_CLUBS_NSLEAD', 'EC_CLUBS_OTHCLUB', 'EC_CLUBS_PEERTUTMEN', 'EC_CLUBS_POLGOV', 'EC_CLUBS_ROBOTICS', 'EC_CLUBS_SCHOOLCOM', 'EC_CLUBS_SPCHDEB', 'EC_CLUBS_STEM', 'EC_CLUBS_VISARTS', 'EC_SPORTS_BASEBALL', 'EC_SPORTS_BSKTBALL', 'EC_SPORTS_BOWLING', 'EC_SPORTS_DIVING', 'EC_SPORTS_COMPCHEER', 'EC_SPORTS_CROSSCNTRY', 'EC_SPORTS_FOOTBALL', 'EC_SPORTS_GOLF', 'EC_SPORTS_GYMNAST', 'EC_SPORTS_ICEHOCKEY', 'EC_SPORTS_OTHSPRTS', 'EC_SPORTS_POWERLIFT', 'EC_SPORTS_SKIING', 'EC_SPORTS_SOFTBALL', 'EC_SPORTS_SOCCER', 'EC_SPORTS_SWIM', 'EC_SPORTS_TENNIS', 'EC_SPORTS_TRCKFIELD', 'EC_SPORTS_VOLBALL', 'EC_SPORTS_WRSTL']
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
outcomes_statisics = {}

for level in school_levels:
    sample = MIGENEDCOMPLETEVOLUNTARY[MIGENEDCOMPLETEVOLUNTARY[level] == 1]
    outcomes_mean = []
    outcomes_sd = []
    
    for outcome in outcomes:
        
        outcome_mean = sample[outcome].mean()
        outcome_sd = sample[outcome].std()
        
        outcomes_mean.append(outcome_mean)
        outcomes_sd.append(outcome_sd)
    
    outcomes_statisics[level + ' Mean'] = outcomes_mean
    outcomes_statisics[level + ' SD'] = outcomes_sd
    
MIGENEDCOMPLETEVOLUNTARY_OUTCOMES = pd.DataFrame(outcomes_statisics, index=outcomes)

# %%
MIGENEDCOMPLETEVOLUNTARY_OUTCOMES

# %%
MIGENEDCOMPLETEVOLUNTARY_OUTCOMES.to_csv("C:/Users/johnw/Box/Michigan Parent Dashboard/Tables/MIGENEDCOMPLETEVOLUNTARY_OUTCOMES_06_26_23.csv", index=True)

# %%
# Sample data for numextracurricular
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARY[MIGENEDCOMPLETEVOLUNTARY[level] == 1]['numextracurricular'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numextracurricular')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numclubs
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARY[MIGENEDCOMPLETEVOLUNTARY[level] == 1]['numclubs'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numclubs')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numsports
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARY[MIGENEDCOMPLETEVOLUNTARY[level] == 1]['numsports'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numsports')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Complete Predictors AND Voluntary Information AND At Least 1 ECA

# %%
outcomes = ['numextracurricular', 'numclubs', 'numsports', 'EC_CLUBS_CARFOC', 'EC_CLUBS_GAMES', 'EC_CLUBS_HONSOC', 'EC_CLUBS_LITHUM', 'EC_CLUBS_MUSIC', 'EC_CLUBS_NSLEAD', 'EC_CLUBS_OTHCLUB', 'EC_CLUBS_PEERTUTMEN', 'EC_CLUBS_POLGOV', 'EC_CLUBS_ROBOTICS', 'EC_CLUBS_SCHOOLCOM', 'EC_CLUBS_SPCHDEB', 'EC_CLUBS_STEM', 'EC_CLUBS_VISARTS', 'EC_SPORTS_BASEBALL', 'EC_SPORTS_BSKTBALL', 'EC_SPORTS_BOWLING', 'EC_SPORTS_DIVING', 'EC_SPORTS_COMPCHEER', 'EC_SPORTS_CROSSCNTRY', 'EC_SPORTS_FOOTBALL', 'EC_SPORTS_GOLF', 'EC_SPORTS_GYMNAST', 'EC_SPORTS_ICEHOCKEY', 'EC_SPORTS_OTHSPRTS', 'EC_SPORTS_POWERLIFT', 'EC_SPORTS_SKIING', 'EC_SPORTS_SOFTBALL', 'EC_SPORTS_SOCCER', 'EC_SPORTS_SWIM', 'EC_SPORTS_TENNIS', 'EC_SPORTS_TRCKFIELD', 'EC_SPORTS_VOLBALL', 'EC_SPORTS_WRSTL']
school_levels = ('All','Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')
outcomes_statisics = {}

for level in school_levels:
    sample = MIGENEDCOMPLETEVOLUNTARYWITHECA[MIGENEDCOMPLETEVOLUNTARYWITHECA[level] == 1]
    outcomes_mean = []
    outcomes_sd = []
    
    for outcome in outcomes:
        
        outcome_mean = sample[outcome].mean()
        outcome_sd = sample[outcome].std()
        
        outcomes_mean.append(outcome_mean)
        outcomes_sd.append(outcome_sd)
    
    outcomes_statisics[level + ' Mean'] = outcomes_mean
    outcomes_statisics[level + ' SD'] = outcomes_sd
    
MIGENEDCOMPLETEVOLUNTARYWITHECA_OUTCOMES = pd.DataFrame(outcomes_statisics, index=outcomes)

# %%
MIGENEDCOMPLETEVOLUNTARYWITHECA_OUTCOMES

# %%
MIGENEDCOMPLETEVOLUNTARYWITHECA_OUTCOMES.to_csv("C:/Users/johnw/Box/Michigan Parent Dashboard/Tables/MIGENEDCOMPLETEVOLUNTARYWITHECA_OUTCOMES_06_26_23.csv", index=True)

# %%
# Sample data for numextracurricular
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARYWITHECA[MIGENEDCOMPLETEVOLUNTARYWITHECA[level] == 1]['numextracurricular'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numextracurricular')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numclubs
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARYWITHECA[MIGENEDCOMPLETEVOLUNTARYWITHECA[level] == 1]['numclubs'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numclubs')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data for numsports
numextracurricular = np.random.randint(0, 10, size=(100,))
school_levels = ('Elementary School', 'Elementary/Middle School', 'Elementary through High School', 'Middle School', 'Middle/High School', 'High School')

# Create separate histograms for each school level
for level in school_levels:
    plt.hist(MIGENEDCOMPLETEVOLUNTARYWITHECA[MIGENEDCOMPLETEVOLUNTARYWITHECA[level] == 1]['numsports'], bins=10, alpha=0.5, label=level)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.title('numsports')

# Add legend
plt.legend()

# Show the plot
plt.show()
